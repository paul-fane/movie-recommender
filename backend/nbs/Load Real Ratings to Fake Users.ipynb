# %%
# Having jupiter comunicating with django
import setup_django
setup_django.init()

# %%
import pandas as pd
from django.conf import settings

ratings_path = settings.DATA_DIR / "ratings_small.csv" #pathlib
ratings_path.exists()
# Out:
# True

# %%
df = pd.read_csv(ratings_path)

# %%
df.head(n=10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
# 5       1     1263     2.0  1260759151
# 6       1     1287     2.0  1260759187
# 7       1     1293     2.0  1260759148
# 8       1     1339     3.5  1260759125
# 9       1     1343     2.0  1260759131

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

# %%
current_users = User.objects.all().values_list('id', flat=True)
rating_users = df['userId'].tolist()

# %%
missing_user_ids = set(rating_users) - set(current_users)
missing_user_ids
# Out:
# set()

# %%
for uid in missing_user_ids:
    User.objects.create(
        id=uid,
        username=f"missing-user-{uid}"
    )
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\backends\utils.py:105, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#     104 else:
# --> 105     return self.cursor.execute(sql, params)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\backends\sqlite3\base.py:329, in SQLiteCursorWrapper.execute(self, query, params)
#     328 query = self.convert_query(query, param_names=param_names)
# --> 329 return super().execute(query, params)
#
# IntegrityError: UNIQUE constraint failed: auth_user.id
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 for uid in missing_user_ids:
# ----> 2     User.objects.create(
#       3         id=uid,
#       4         username=f"missing-user-{uid}"
#       5     )
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\query.py:679, in QuerySet.create(self, **kwargs)
#     677 obj = self.model(**kwargs)
#     678 self._for_write = True
# --> 679 obj.save(force_insert=True, using=self.db)
#     680 return obj
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\contrib\auth\base_user.py:78, in AbstractBaseUser.save(self, *args, **kwargs)
#      77 def save(self, *args, **kwargs):
# ---> 78     super().save(*args, **kwargs)
#      79     if self._password is not None:
#      80         password_validation.password_changed(self._password, self)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\base.py:822, in Model.save(self, force_insert, force_update, using, update_fields)
#     819     if loaded_fields:
#     820         update_fields = frozenset(loaded_fields)
# --> 822 self.save_base(
#     823     using=using,
#     824     force_insert=force_insert,
#     825     force_update=force_update,
#     826     update_fields=update_fields,
#     827 )
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\base.py:909, in Model.save_base(self, raw, force_insert, force_update, using, update_fields)
#     905         force_insert = self._validate_force_insert(force_insert)
#     906         parent_inserted = self._save_parents(
#     907             cls, using, update_fields, force_insert
#     908         )
# --> 909     updated = self._save_table(
#     910         raw,
#     911         cls,
#     912         force_insert or parent_inserted,
#     913         force_update,
#     914         using,
#     915         update_fields,
#     916     )
#     917 # Store the database on which the object was saved
#     918 self._state.db = using
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\base.py:1071, in Model._save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#    1065 fields = [
#    1066     f
#    1067     for f in meta.local_concrete_fields
#    1068     if not f.generated and (pk_set or f is not meta.auto_field)
#    1069 ]
#    1070 returning_fields = meta.db_returning_fields
# -> 1071 results = self._do_insert(
#    1072     cls._base_manager, using, fields, returning_fields, raw
#    1073 )
#    1074 if results:
#    1075     for value, field in zip(results[0], returning_fields):
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\base.py:1112, in Model._do_insert(self, manager, using, fields, returning_fields, raw)
#    1107 def _do_insert(self, manager, using, fields, returning_fields, raw):
#    1108     """
#    1109     Do an INSERT. If returning_fields is defined then this method should
#    1110     return the newly created data for the model.
#    1111     """
# -> 1112     return manager._insert(
#    1113         [self],
#    1114         fields=fields,
#    1115         returning_fields=returning_fields,
#    1116         using=using,
#    1117         raw=raw,
#    1118     )
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\query.py:1847, in QuerySet._insert(self, objs, fields, returning_fields, raw, using, on_conflict, update_fields, unique_fields)
#    1840 query = sql.InsertQuery(
#    1841     self.model,
#    1842     on_conflict=on_conflict,
#    1843     update_fields=update_fields,
#    1844     unique_fields=unique_fields,
#    1845 )
#    1846 query.insert_values(fields, objs, raw=raw)
# -> 1847 return query.get_compiler(using=using).execute_sql(returning_fields)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\models\sql\compiler.py:1823, in SQLInsertCompiler.execute_sql(self, returning_fields)
#    1821 with self.connection.cursor() as cursor:
#    1822     for sql, params in self.as_sql():
# -> 1823         cursor.execute(sql, params)
#    1824     if not self.returning_fields:
#    1825         return []
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\backends\utils.py:122, in CursorDebugWrapper.execute(self, sql, params)
#     120 def execute(self, sql, params=None):
#     121     with self.debug_sql(sql, params, use_last_executed_query=True):
# --> 122         return super().execute(sql, params)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\backends\utils.py:79, in CursorWrapper.execute(self, sql, params)
#      78 def execute(self, sql, params=None):
# ---> 79     return self._execute_with_wrappers(
#      80         sql, params, many=False, executor=self._execute
#      81     )
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\backends\utils.py:92, in CursorWrapper._execute_with_wrappers(self, sql, params, many, executor)
#      90 for wrapper in reversed(self.db.execute_wrappers):
#      91     executor = functools.partial(wrapper, executor)
# ---> 92 return executor(sql, params, many, context)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\backends\utils.py:100, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#      98     warnings.warn(self.APPS_NOT_READY_WARNING_MSG, category=RuntimeWarning)
#      99 self.db.validate_no_broken_transaction()
# --> 100 with self.db.wrap_database_errors:
#     101     if params is None:
#     102         # params default might be backend specific.
#     103         return self.cursor.execute(sql)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\utils.py:91, in DatabaseErrorWrapper.__exit__(self, exc_type, exc_value, traceback)
#      89 if dj_exc_type not in (DataError, IntegrityError):
#      90     self.wrapper.errors_occurred = True
# ---> 91 raise dj_exc_value.with_traceback(traceback) from exc_value
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\backends\utils.py:105, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#     103     return self.cursor.execute(sql)
#     104 else:
# --> 105     return self.cursor.execute(sql, params)
#
# File ~\Desktop\Netflix-Clone\.venv\Lib\site-packages\django\db\backends\sqlite3\base.py:329, in SQLiteCursorWrapper.execute(self, query, params)
#     327 param_names = list(params) if isinstance(params, Mapping) else None
#     328 query = self.convert_query(query, param_names=param_names)
# --> 329 return super().execute(query, params)
#
# IntegrityError: UNIQUE constraint failed: auth_user.id

# %%
import math
from decimal import Decimal

# %%
df['value'] = df['rating'].apply(lambda x: math.ceil(Decimal(x)))
df.head()
# Out:
#    userId  movieId  rating   timestamp  value
# 0       1       31     2.5  1260759144      3
# 1       1     1029     3.0  1260759179      3
# 2       1     1061     3.0  1260759182      3
# 3       1     1129     2.0  1260759185      2
# 4       1     1172     4.0  1260759205      4

# %%
df['user_id'] = df['userId']
df['object_id'] = df['movieId']

# %%
df.head()
# Out:
#    userId  movieId  rating   timestamp  value  user_id  object_id
# 0       1       31     2.5  1260759144      3        1         31
# 1       1     1029     3.0  1260759179      3        1       1029
# 2       1     1061     3.0  1260759182      3        1       1061
# 3       1     1129     2.0  1260759185      2        1       1129
# 4       1     1172     4.0  1260759205      4        1       1172

# %%
cols = ['user_id', 'value', 'object_id']
transformed_df = df.copy()[cols]

# %%
rating_records = transformed_df.to_dict('records')

# %%
from ratings.models import Rating
qs = Rating.objects.all()
qs.delete()
# Out:
# (13413, {'ratings.Rating': 13413})

# %%
from django.contrib.contenttypes.models import ContentType

ctype = ContentType.objects.get(app_label='playlists', model='movieproxy')

# %%
ctype
# Out:
# <ContentType: Playlists | Movie>

# %%
new_ratings = []
for r in rating_records:
    r['content_type'] = ctype
    new_ratings.append(
        Rating(**r)
    )
Rating.objects.bulk_create(new_ratings, ignore_conflicts=True, batch_size=1000)
# Out:
# [<Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  <Rating: Rating object (None)>,
#  ...]

# %%
from ratings.tasks import task_update_movie_ratings

task_update_movie_ratings()
# Out:
# Rating update took 0:00:00 (0.002996206283569336s)
